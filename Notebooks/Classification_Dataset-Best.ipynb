# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import random
# import uuid
from random import randrange
# from datetime import timedelta
# from datetime import datetime

# %%
dataset_df = pd.read_csv("C:/Users/pasin/OneDrive/Desktop/DatasetBest.csv");

# %%
def generate_quiz_scores() :
#     return random.randint(20, 45)
#     return random.randint(45, 75)
    return random.randint(75, 100)

def generate_quiz_time() :
    return round(random.uniform(2.5,4.5),1)

# %%
dataset_df["quiz1"] = dataset_df.apply(lambda x: generate_quiz_scores(), axis=1)
dataset_df["time1"] = dataset_df.apply(lambda x: generate_quiz_time(), axis=1)

# %%
dataset_df["quiz2"] = dataset_df.apply(lambda x: generate_quiz_scores(), axis=1)
dataset_df["time2"] = dataset_df.apply(lambda x: generate_quiz_time(), axis=1)

# %%
dataset_df["quiz3"] = dataset_df.apply(lambda x: generate_quiz_scores(), axis=1)
dataset_df["time3"] = dataset_df.apply(lambda x: generate_quiz_time(), axis=1)

# %%
dataset_df
# Out:
#      Unnamed: 0  Unnamed: 0.1 student_id  quiz1  time1  quiz2  time2  quiz3  \
# 0             0             0      ST001     93    2.6     81    3.0     84
# 1             1             1      ST002     76    4.0     96    2.8     94
# 2             2             2      ST003     76    2.6     97    4.0     89
# 3             3             3      ST004     91    4.1     92    3.6     87
# 4             4             4      ST005     80    3.3     87    3.4     96
# ..          ...           ...        ...    ...    ...    ...    ...    ...
# 195         195           195      ST196     98    3.4     81    4.3     80
# 196         196           196      ST197     94    3.1     81    2.7     95
# 197         197           197      ST198     94    2.6     80    3.1     82
# 198         198           198      ST199     92    4.4     89    2.8     98
# 199         199           199      ST200     84    3.9     82    3.6     75
#
#      time3
# 0      2.7
# 1      4.3
# 2      2.8
# 3      2.9
# 4      4.0
# ..     ...
# 195    3.6
# 196    4.4
# 197    3.6
# 198    3.8
# 199    3.4
#
# [200 rows x 9 columns]

# %%
dataset_df.to_csv("C:/Users/pasin/OneDrive/Desktop/DatasetBest.csv");
